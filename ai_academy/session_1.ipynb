# %% [markdown]
# # Programming AMD GPUs with HIP Session 1
#
# In this notebook, you will ....
#
# ## Recommended Hardware
#
# This notebook can run on the following hardware or remote resources.
#
# ✅ AMD Instinct™ Accelerators
# ✅ AMD Radeon™ RX/PRO Graphics Cards
#
# [![Open in AMD Developer Cloud](https://img.shields.io/badge/Open_in_AMD_Developer_Cloud-000000?logo=amd&logoSize=auto)](https://amd-ai-academy.com/github/mariodruiz/introduction_to_hip/blob/mockup/ai_academy/session_1.ipynb)
#
# ## Software Environment
#
# Install ROCm on your system.
#
# | Linux | Windows |
# |-------|---------|
# | [Install PyTorch](https://rocm.docs.amd.com/projects/install-on-linux/en/latest/install/quick-start.html) | [PyTorch on Windows](https://rocm.docs.amd.com/projects/radeon-ryzen/en/latest/docs/install/installrad/windows/install-pytorch.html)|
# | [Install Docker container](https://amdresearch.github.io/aup-ai-tutorials//env/env-gpu.html) | |
#
# ## Goals
#
# ....

# %% [markdown]
# To get started run the cells below to get the HIP examples and exercises for this session

# %%
# !pip install pygit2

# %%
import pygit2, shutil
repo = pygit2.clone_repository('https://github.com/mariodruiz/introduction_to_hip.git', '/tmp/introduction_to_hip', checkout_branch='mockup')
shutil.copytree('/tmp/introduction_to_hip/ai_academy/session_1/', 'session_1')

# %% [markdown]
# This session has 4 directories with code
#
# ```sh
# /workspace
# ├── session_1
# │   ├── 01_vector_addition
# │   ├── 02_error_check
# │   ├── 03_add_d2h_data_transfer
# │   └── 04_complete_square_elements
# ```

# %% [markdown]
# Now you can open the terminal and navigate to `/workspace/session_1/01_vector_addition` to run the example.
#
# If you are not familiar with using the command line to run code, the patter is the following
#
# 1. navigate to the directory, use `cd`
# 1. compile code, use `make`
# 1. run code, `./<executable>`

# %% [markdown]
# To run the first example following these steps in the command line
#
# ```sh
# cd /workspace/session_1/01_vector_addition
# make
# ./vector_addition
# ```
#
# The output should look like this
#
# ```console
# ==============================
# __SUCCESS__
# ------------------------------
# N                : 1048576
# Blocks in Grid   : 4096
# Threads per Block: 256
# ==============================
# ```

# %% [markdown]
# Now, you can continue to the exercises
